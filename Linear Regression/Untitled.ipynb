# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
from sklearn import linear_model
# %matplotlib inline

# %%
df=pd.read_csv("homeprices.csv")
df.head()
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.scatter(df.area,df.price,color="red",marker="^")
plt.xlabel("Area(sq.ft)")
plt.ylabel("Price(in $)")
# Out:
# Text(0, 0.5, 'Price(in $)')

# %%
reg= linear_model.LinearRegression()
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %%
135.7876*3500+180616.43835
# Out:
# 655873.03835

# %%
reg.predict([[3300]])
# Out:
# C:\Users\chott\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
plt.scatter(df.area,df.price,color="red",marker="^")
plt.plot(df.area,reg.predict(df[['area']]),color="blue")
plt.title("Univariate Linear Regression")
plt.xlabel("Area(sq.ft)")
plt.ylabel("Price(in $)")
# Out:
# Text(0, 0.5, 'Price(in $)')

# %%
df=pd.read_csv("canada_per_capita_income.csv")
df.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
plt.plot(df['year'], df['per capita income (US$)'], lw=2, c="slategrey")
plt.xlabel('Year')
plt.ylabel('Per Capita Income (US$)')
plt.title('Per Capita Income Over the Years')
# Out:
# Text(0.5, 1.0, 'Per Capita Income Over the Years')

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['year']],df['per capita income (US$)'])
# Out:
# LinearRegression()

# %%
reg.predict([[2020]])
# Out:
# C:\Users\chott\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])

# %%
reg.coef_
# Out:
# array([828.46507522])

# %%
reg.intercept_
# Out:
# -1632210.7578554575

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
from sklearn.linear_model import LinearRegression
# %matplotlib inline

# %%
df=pd.read_csv("canada_per_capita_income.csv")
df.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
plt.plot(df["year"],df["per capita income (US$)"],color="coral",lw=1.5)
plt.xlabel("Year")
plt.ylabel("Income (US$)")
plt.title("Canada per capita income",loc="left")
# Out:
# Text(0.0, 1.0, 'Canada per capita income')

# %%
reg=LinearRegression()

# %%
reg.fit(df[['year']],df['per capita income (US$)'])
# Out:
# LinearRegression()

# %%
reg.predict([[2014]])
# Out:
# C:\Users\chott\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([36317.90364308])

# %%
reg.intercept_
# Out:
# -1632210.7578554575

# %%
reg.coef_
# Out:
# array([828.46507522])
