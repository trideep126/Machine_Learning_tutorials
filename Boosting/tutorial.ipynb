# %%
import pandas as pd
from sklearn.datasets import load_diabetes
diabetes=load_diabetes()
dir(diabetes)
# Out:
# ['DESCR',
#  'data',
#  'data_filename',
#  'data_module',
#  'feature_names',
#  'frame',
#  'target',
#  'target_filename']

# %%
df=pd.DataFrame(diabetes.data,columns=diabetes.feature_names)
df
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 0   -0.002592  0.019907 -0.017646
# ...

# %%
df['Target']=diabetes.target
df
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6  Target
# ...

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6',
#        'Target'],
#       dtype='object')

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
features=df[['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']]
scaled_features=scaler.fit_transform(features)
df[features.columns]=scaled_features
df[['Target']]=scaler.fit_transform(df[['Target']])
df
# Out:
#           age  sex       bmi        bp        s1        s2        s3  \
# 0    0.666667  1.0  0.582645  0.549296  0.294118  0.256972  0.207792
# 1    0.483333  0.0  0.148760  0.352113  0.421569  0.306773  0.623377
# 2    0.883333  1.0  0.516529  0.436620  0.289216  0.258964  0.246753
# 3    0.083333  0.0  0.301653  0.309859  0.495098  0.447211  0.233766
# 4    0.516667  0.0  0.206612  0.549296  0.465686  0.417331  0.389610
# ..        ...  ...       ...       ...       ...       ...       ...
# 437  0.683333  1.0  0.421488  0.704225  0.431373  0.359562  0.259740
# 438  0.466667  1.0  0.285124  0.183099  0.627451  0.619522  0.259740
# 439  0.683333  1.0  0.285124  0.530563  0.318627  0.323705  0.272727
# 440  0.283333  0.0  0.495868  0.464789  0.509804  0.416335  0.259740
# 441  0.283333  0.0  0.066116  0.126761  0.750000  0.456175  0.974026
#
#            s4        s5        s6    Target
# 0    0.282087  0.562217  0.439394  0.392523
# 1    0.141044  0.222437  0.166667  0.155763
# ...

# %%
X=df.drop(['Target'],axis='columns')
y=df[['Target']]

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR

# %%
lr=RandomizedSearchCV(LinearRegression(),{},cv=5,n_iter=10,return_train_score=False)

tree=RandomizedSearchCV(DecisionTreeRegressor(),{
    'max_leaf_nodes':[10,20,30,40],
    'criterion':['absolute_error', 'friedman_mse', 'squared_error', 'poisson']
},cv=5,n_iter=10,return_train_score=False)

rf=RandomizedSearchCV(RandomForestRegressor(),{
    'n_estimators':[1,5,10,20]
},cv=5,n_iter=10,return_train_score=False)

svm=RandomizedSearchCV(SVR(gamma='auto'),{
    'C':[1,10,20],
    'kernel':['rbf','linear','poly','sigmoid']
},cv=5,n_iter=10,return_train_score=False)

# %%
lr.fit(X,y)
tree.fit(X,y)
rf.fit(X,y)
svm.fit(X,y)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:305: UserWarning: The total space of parameters 1 is smaller than n_iter=10. Running 1 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:305: UserWarning: The total space of parameters 4 is smaller than n_iter=10. Running 4 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
print(f"Linear Regression: {lr.best_params_} \t Best Score: {lr.best_score_}")
print(f"Decision Tree: {tree.best_params_} \t Best Score: {tree.best_score_}")
print(f"Random Forest: {rf.best_params_} \t Best Score: {rf.best_score_}")
print(f"SVM: {svm.best_params_} \t Best Score: {svm.best_score_}")
# Out:
# Linear Regression: {} 	 Best Score: 0.4823164359086422
# Decision Tree: {'max_leaf_nodes': 10, 'criterion': 'squared_error'} 	 Best Score: 0.2738708682841476
# Random Forest: {'n_estimators': 20} 	 Best Score: 0.4014216561803652
# SVM: {'kernel': 'rbf', 'C': 1} 	 Best Score: 0.4954069206008545

# %% [markdown]
# As we can see none of the Regression models give an appropriate accuracy score, hence we may apply some other Boosting Techniques

# %%
from sklearn.ensemble import AdaBoostRegressor,GradientBoostingRegressor
from xgboost import XGBRegressor

# %% [markdown]
# #### **Adaboost**(Adaptive Boosting) - sequentially adds predictors to an ensemble, where each predictor focuses on the errors made by previous predictors.
# Simple and less prone to overfitting but can be sensitive to noisy data and outliers
#
# #### **Gradient Boosting** - sequentially builds an ensemble of trees where each new tree attempts to correct the errors of the combined ensemble of all previous trees by minimizing a loss function.
# Provides high prediction accuracy but can be computationally intensive
#
# #### **XGboost** - optimized version of gradient boosting, incorporates enhancements like tree pruning, regularization.
# Highly efficient and scalable but requires careful tuning of hyperparameters for optimal performance

# %%
ab= RandomizedSearchCV(AdaBoostRegressor(),{
    'n_estimators':[100,200,300],
    'learning_rate':[0.01,0.1,0.2,0.5],
    'loss':['linear', 'square', 'exponential']
},cv=4,n_iter=3,return_train_score=False)

gb=RandomizedSearchCV(GradientBoostingRegressor(),{
    'n_estimators':[100,200,300],
    'learning_rate':[0.01,0.1,0.2,0.5],
    'max_depth':[3,5,7],
    'loss':['squared_error', 'absolute_error', 'huber', 'quantile'],
    'subsample':[0.6,0.8,1.0],
    'criterion':['friedman_mse', 'squared_error']
},cv=4,n_iter=3,return_train_score=False)

xgb=RandomizedSearchCV(XGBRegressor(),{
    'n_estimators': [100, 200, 300],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 5, 7],
    'subsample': [0.6, 0.8, 1.0],
    'colsample_bytree': [0.6, 0.8, 1.0]
},cv=4,n_iter=3,return_train_score=False)

# %%
ab.fit(X,y)
gb.fit(X,y)
xgb.fit(X,y)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
print(f"AdaBoost: {ab.best_params_} \t Score: {ab.best_score_}")
print(f"Gradient Boosting: {gb.best_params_} \t Score: {gb.best_score_}")
print(f"XGBoost: {xgb.best_params_} \t Score: {xgb.best_score_}")
# Out:
# AdaBoost: {'n_estimators': 300, 'loss': 'linear', 'learning_rate': 0.01} 	 Score: 0.43221376929334887
# Gradient Boosting: {'subsample': 0.8, 'n_estimators': 200, 'max_depth': 5, 'loss': 'huber', 'learning_rate': 0.01, 'criterion': 'squared_error'} 	 Score: 0.41900955133641904
# XGBoost: {'subsample': 1.0, 'n_estimators': 100, 'max_depth': 7, 'learning_rate': 0.1, 'colsample_bytree': 0.8} 	 Score: 0.36658611994388746
